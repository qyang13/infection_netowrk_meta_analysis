# %% [markdown]
# # Process input logFC and Padj files, calculate pair-wise Spearman CC

# %% [markdown]
# ## Imports

# %%
import os
import scipy as sp
import numpy as np

# %% [markdown]
# ## Process input logFC and Padj files from DEseq
